# %%
import requests
from bs4 import BeautifulSoup


URL = "https://www.energy-storage.news/market-segments/grid-scale/"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# <div class="elementor-widget-container">
# results = soup.find(class_="jet-listing-grid__items grid-col-desk-1 grid-col-tablet-1 grid-col-mobile-1 jet-listing-grid--513")
results = soup.find(class_="elementor-widget-container")
all_results = soup.select('.jet-listing-dynamic-post-53757 > div:nth-child(1) > section:nth-child(1) > div:nth-child(2) > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div:nth-child(1)')

container_results = soup.select('.elementor-element .elementor-widget-container .elementor-widget-container')
# container_results = soup.select(".elementor-element .elementor-element-79cd234 .elementor-widget .elementor-widget-text-editor")

# print(page.text)
# print(results.prettify())
# print(all_results)
print(container_results)
for item in container_results:
    print(item)
# Out:
# [<div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/ontario-makes-canadas-biggest-ever-battery-storage-procurement-to-meet-target/">
# <img alt="transferability tax credit investment ITC BESS PRoject Aypa" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/BESS-Project-Aypa-qfara1jm1inrcq4ub05b282b95rt3hw86whoguc79g.jpg" title="BESS Project Aypa" width="400"/> </a>
# </div>, <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/ontario-makes-canadas-biggest-ever-battery-storage-procurement-to-meet-target/">Ontario makes Canada’s biggest-ever battery storage procurement to meet target</a></h2> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 10, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# Ontario’s Independent Electricity System Operator (IESO) has made Canada’s biggest energy storage procurement to date, selecting nearly 1.8GW of projects through a Request for Proposals (RFP). </div>, <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/how-a-flexibility-gap-could-derail-the-european-energy-transition-and-how-we-can-fix-it/">
# <img alt="flexiblity" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/wartsila-black-hillock-qjuh4cbkker7z5be28oqzrox7lxwtv1anz8xuvgjic.jpg" title="wartsila black hillock" width="400"/> </a>
# </div>, <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/how-a-flexibility-gap-could-derail-the-european-energy-transition-and-how-we-can-fix-it/">How a ‘flexibility gap’ could derail the European energy transition – and how we can fix it</a></h2> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 10, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# Much more needs to be done to ensure that European countries create the right investment environment for flexibility resources in the electricity system, writes Eaton’s Siobahn Meikle. </div>, <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/barbados-regulator-knocks-back-utilitys-90mw-bess-proposal-pending-cost-benefit-analysis/">
# <img alt="Barbados Light &amp; Power's 10MW St Lucy Energy Gateway solar PV plant. Image: BLPC via X/Twitter." height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/barbados-st-lucy-pv-barbados-light-and-power-co-via-X-qny8c7i0y6oncqp325jj1yp4iswos9gy0ptqwek6v8.jpg" title="barbados st lucy pv barbados light and power co via X" width="400"/> </a>
# </div>, <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/barbados-regulator-knocks-back-utilitys-90mw-bess-proposal-pending-cost-benefit-analysis/">Barbados regulator knocks back utility’s 90MW BESS proposal pending cost-benefit analysis</a></h2> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 10, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# A cost recovery application for 90MW of battery storage, filed by Barbados Light &amp; Power Company (BLPC), has been only partially approved by the eastern Caribbean island nation’s regulator. </div>, <div class="elementor-widget-container">
# <div id="div-gpt-ad-1619444090098-0">
# <script>googletag.cmd.push(function() {googletag.display('div-gpt-ad-1619444090098-0');});
#     </script>
# </div> </div>, <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/energy-vault-china-project-commissioned-new-aus-bess-order-but-big-revenue-drop-in-2024/">
# <img alt="energy vault gravity energy storage system evx china" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/Energy-Vault-qab7x1ofanx0xg9hwd2v5gnyvwsb78gviwbsugrrus.jpg" title="Energy Vault" width="400"/> </a>
# </div>, <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/energy-vault-china-project-commissioned-new-aus-bess-order-but-big-revenue-drop-in-2024/">Energy Vault China project commissioned, new Aus BESS order, but big revenue drop in 2024</a></h2> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 10, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# Commissioning has been completed on the first commercial-scale project using Energy Vault’s gravity energy storage technology, while the firm has also secured a 400MWh BESS order for a project in Australia. However, it expects revenues this year to be 70-85% lower than 2023. </div>, <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/netherlands-non-firm-grid-connections-and-lower-fees-could-double-bess-deployments/">
# <img alt="Semperpower rolls-royce catl mtu netherlands battery storage project" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/Semperpower-rolls-royce-catl-mtu-qg2kqtzgss7m7hg1c0r4dfeq1m5qniz0bn88y2ia4k.jpg" title="Semperpower rolls-royce catl mtu" width="400"/> </a>
# </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-terms"><span class="jet-listing-dynamic-terms__link">Premium</span></div> </div>, <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/netherlands-non-firm-grid-connections-and-lower-fees-could-double-bess-deployments/">Netherlands’ ‘non-firm’ grid connections and lower fees could double BESS deployments</a></h2> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# New rules which will reduce grid fees in the Netherlands by providing ‘non-firm agreement’ (NFA) connections as well as time-weighted rates could improve returns and double projected BESS deployments, an analyst has said, though a project owner was less openly optimistic about it. </div>, <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/eaton-and-endurant-energy-deploying-150mwh-of-bess-in-new-york-city/">
# <img alt="Eaton Endurant Energy" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/Eaton-Endurant-qnwriwgitdxt3yg8csxk092jdm7g0uexm4f9g7nav8.jpg" title="Eaton Endurant" width="400"/> </a>
# </div>, <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/eaton-and-endurant-energy-deploying-150mwh-of-bess-in-new-york-city/">Eaton and Endurant Energy deploying 150MWh of BESS in New York City</a></h2> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# Power management tech company Eaton and developer/IPP Endurant Energy are deploying 150MWh of BESS across 10 projects in New York City. </div>, <div class="elementor-widget-container">
# <div id="div-gpt-ad-1646930385796-0">
# <script>googletag.cmd.push(function() {googletag.display('div-gpt-ad-1646930385796-0');});
#     </script>
# </div> </div>, <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/stem-inc-continues-to-guide-for-ebitda-positive-2024-despite-q1-revenue-and-bookings-dip/">
# <img alt="A Stem Inc battery storage project. Image: Stem Inc." height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/CI_Photo_3_Stem_Inc-pb0zo5ss853t1m50a22puk5kna9yyljlptmw5iygg4.png" title="CI_Photo_3_Stem_Inc" width="400"/> </a>
# </div>, <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/stem-inc-continues-to-guide-for-ebitda-positive-2024-despite-q1-revenue-and-bookings-dip/">Stem Inc continues to guide for EBITDA positive 2024 despite Q1 revenue and bookings dip</a></h2> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# Stem Inc has reaffirmed guidance of positive adjusted EBITDA for 2024, despite starting the year with a 62% year-on-year decrease in reported revenues and a fall in bookings. </div>, <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/fluence-revenue-drop-new-5mwh-20-foot-product-and-us-made-modules-for-domestic-content-in-2024/">
# <img alt="Fluence" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/Fluence-Energy-Storage_3_web-q98zmumzvywsh0vkvqx189tjyzoef9i8vzyai7eqpw.jpg" title="Fluence-Energy-Storage_3_web" width="400"/> </a>
# </div>, <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/fluence-revenue-drop-new-5mwh-20-foot-product-and-us-made-modules-for-domestic-content-in-2024/">Fluence revenue drop, new 5MWh 20-foot product and US-made modules for domestic content in 2024</a></h2> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# Global battery energy storage system (BESS) integrator Fluence saw an 11% revenue drop in revenues in the three months ending 31 March, 2024, while it is also launching a higher energy density product and US module production this year. </div>, <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/queensland-to-build-1200mwh-publicly-owned-battery-storage-asset-at-stanwell-coal-power-station/">
# <img alt="A rendering of Stanwell Clean Energy Hub. Image: Queensland government." height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/Stanwell-Clean-Energy-Hub_LR-credit-queensland-government-1-qdfx0q2djv4n5e8rbqejatkn5uxy53dtndrheqk98k.jpg" title="Stanwell Clean Energy Hub_LR credit queensland government" width="400"/> </a>
# </div>, <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/queensland-to-build-1200mwh-publicly-owned-battery-storage-asset-at-stanwell-coal-power-station/">Queensland to build 1,200MWh publicly-owned battery storage asset at Stanwell coal power station</a></h2> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# The state of Queensland, Australia, has committed to investing AU$448 million into battery storage technology at a coal power plant. </div>, <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/regulator-approves-global-energy-alliance-for-people-and-planets-first-project-in-1gw-india-bess-pipeline/">
# <img alt="GEAPP's BESS Consortium launched at last year's COP28 talks. Image: UNclimatechange via Flickr" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/COP28-credit-UNclimate-change-via-flickr-qnwdy4dsysu3vofihixjfldn0jc9exzqevxpkcd6f8.jpg" title="COP28 credit UNclimate change via flickr" width="400"/> </a>
# </div>, <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/regulator-approves-global-energy-alliance-for-people-and-planets-first-project-in-1gw-india-bess-pipeline/">Regulator approves Global Energy Alliance for People and Planet’s first project in 1GW India BESS pipeline</a></h2> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# Regulatory approval has been granted for what is claimed to be India’s first commercial standalone battery storage project. </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/breaking-communication-barriers-between-asset-management-and-om-is-essential-for-ess-operations/">Breaking communication barriers between asset management and O&amp;M is essential for ESS operations</a></h3> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-terms"><span class="jet-listing-dynamic-terms__link">Premium</span></div> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/uk-residential-market-moving-from-solar-coupled-to-battery-first-says-givenergy/">UK residential market moving from solar-coupled to ‘battery first’, says GivEnergy</a></h3> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/india-tata-power-signs-ppa-for-firm-dispatchable-energy-from-wind-solar-and-storage/">India: Tata Power signs PPA for firm, dispatchable energy from wind, solar and storage</a></h3> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-terms"><span class="jet-listing-dynamic-terms__link">Premium</span></div> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/powin-says-diversity-of-bess-cell-supply-key-to-solving-post-pandemic-procurement-challenges/">Powin says diversity of BESS cell supply key to solving post-pandemic procurement challenges</a></h3> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-terms"><span class="jet-listing-dynamic-terms__link">Premium</span></div> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/netherlands-non-firm-grid-connections-and-lower-fees-could-double-bess-deployments/">Netherlands’ ‘non-firm’ grid connections and lower fees could double BESS deployments</a></h3> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/powin-joins-5mwh-bess-container-club-with-new-pod-unit/">Powin joins 5MWh BESS container club with new ‘Pod’ unit</a></h3> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://re-plus.events/texas/" target="_blank">RE+ Texas 2024</a></h3> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 14</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - May 15</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">Houston, Texas</div></div></div> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://app.livestorm.co/solar-media/learn-how-innovations-in-insurance-unlock-the-full-potential-of-battery-storage-systems?utm_source=ESN&amp;utm_medium=event-listings" target="_blank">Learn how innovations in insurance unlock the full potential of battery storage systems</a></h3> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 15</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - May 15</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">8am (EDT) / 2pm (CEST)</div></div></div> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://storageaustralia.solarenergyevents.com/" target="_blank">Energy Storage Summit Australia 2024</a></h3> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 21</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - May 22</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">Sydney, Australia</div></div></div> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.pvtechconferences.com/pv-moduletech-usa/?utm_source=calendar&amp;utm_medium=website&amp;utm_campaign=continual" target="_blank">PV ModuleTech USA 2024</a></h3> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 21</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - May 22</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">Napa, USA</div></div></div> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://renewablerevenue.co.uk/" target="_blank">Renewable Energy Revenues Summit 2024</a></h3> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 22</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - May 23</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">London, UK </div></div></div> </div>, <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://acore.org/events/finance-forum/" target="_blank">ACORE Finance Forum 2024</a></h3> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">June 4</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - June 5</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>, <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">New York, USA</div></div></div> </div>]
# <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/ontario-makes-canadas-biggest-ever-battery-storage-procurement-to-meet-target/">
# <img alt="transferability tax credit investment ITC BESS PRoject Aypa" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/BESS-Project-Aypa-qfara1jm1inrcq4ub05b282b95rt3hw86whoguc79g.jpg" title="BESS Project Aypa" width="400"/> </a>
# </div>
# <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/ontario-makes-canadas-biggest-ever-battery-storage-procurement-to-meet-target/">Ontario makes Canada’s biggest-ever battery storage procurement to meet target</a></h2> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 10, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# Ontario’s Independent Electricity System Operator (IESO) has made Canada’s biggest energy storage procurement to date, selecting nearly 1.8GW of projects through a Request for Proposals (RFP). </div>
# <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/how-a-flexibility-gap-could-derail-the-european-energy-transition-and-how-we-can-fix-it/">
# <img alt="flexiblity" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/wartsila-black-hillock-qjuh4cbkker7z5be28oqzrox7lxwtv1anz8xuvgjic.jpg" title="wartsila black hillock" width="400"/> </a>
# </div>
# <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/how-a-flexibility-gap-could-derail-the-european-energy-transition-and-how-we-can-fix-it/">How a ‘flexibility gap’ could derail the European energy transition – and how we can fix it</a></h2> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 10, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# Much more needs to be done to ensure that European countries create the right investment environment for flexibility resources in the electricity system, writes Eaton’s Siobahn Meikle. </div>
# <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/barbados-regulator-knocks-back-utilitys-90mw-bess-proposal-pending-cost-benefit-analysis/">
# <img alt="Barbados Light &amp; Power's 10MW St Lucy Energy Gateway solar PV plant. Image: BLPC via X/Twitter." height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/barbados-st-lucy-pv-barbados-light-and-power-co-via-X-qny8c7i0y6oncqp325jj1yp4iswos9gy0ptqwek6v8.jpg" title="barbados st lucy pv barbados light and power co via X" width="400"/> </a>
# </div>
# <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/barbados-regulator-knocks-back-utilitys-90mw-bess-proposal-pending-cost-benefit-analysis/">Barbados regulator knocks back utility’s 90MW BESS proposal pending cost-benefit analysis</a></h2> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 10, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# A cost recovery application for 90MW of battery storage, filed by Barbados Light &amp; Power Company (BLPC), has been only partially approved by the eastern Caribbean island nation’s regulator. </div>
# <div class="elementor-widget-container">
# <div id="div-gpt-ad-1619444090098-0">
# <script>googletag.cmd.push(function() {googletag.display('div-gpt-ad-1619444090098-0');});
#     </script>
# </div> </div>
# <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/energy-vault-china-project-commissioned-new-aus-bess-order-but-big-revenue-drop-in-2024/">
# <img alt="energy vault gravity energy storage system evx china" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/Energy-Vault-qab7x1ofanx0xg9hwd2v5gnyvwsb78gviwbsugrrus.jpg" title="Energy Vault" width="400"/> </a>
# </div>
# <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/energy-vault-china-project-commissioned-new-aus-bess-order-but-big-revenue-drop-in-2024/">Energy Vault China project commissioned, new Aus BESS order, but big revenue drop in 2024</a></h2> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 10, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# Commissioning has been completed on the first commercial-scale project using Energy Vault’s gravity energy storage technology, while the firm has also secured a 400MWh BESS order for a project in Australia. However, it expects revenues this year to be 70-85% lower than 2023. </div>
# <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/netherlands-non-firm-grid-connections-and-lower-fees-could-double-bess-deployments/">
# <img alt="Semperpower rolls-royce catl mtu netherlands battery storage project" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/Semperpower-rolls-royce-catl-mtu-qg2kqtzgss7m7hg1c0r4dfeq1m5qniz0bn88y2ia4k.jpg" title="Semperpower rolls-royce catl mtu" width="400"/> </a>
# </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-terms"><span class="jet-listing-dynamic-terms__link">Premium</span></div> </div>
# <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/netherlands-non-firm-grid-connections-and-lower-fees-could-double-bess-deployments/">Netherlands’ ‘non-firm’ grid connections and lower fees could double BESS deployments</a></h2> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# New rules which will reduce grid fees in the Netherlands by providing ‘non-firm agreement’ (NFA) connections as well as time-weighted rates could improve returns and double projected BESS deployments, an analyst has said, though a project owner was less openly optimistic about it. </div>
# <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/eaton-and-endurant-energy-deploying-150mwh-of-bess-in-new-york-city/">
# <img alt="Eaton Endurant Energy" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/Eaton-Endurant-qnwriwgitdxt3yg8csxk092jdm7g0uexm4f9g7nav8.jpg" title="Eaton Endurant" width="400"/> </a>
# </div>
# <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/eaton-and-endurant-energy-deploying-150mwh-of-bess-in-new-york-city/">Eaton and Endurant Energy deploying 150MWh of BESS in New York City</a></h2> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# Power management tech company Eaton and developer/IPP Endurant Energy are deploying 150MWh of BESS across 10 projects in New York City. </div>
# <div class="elementor-widget-container">
# <div id="div-gpt-ad-1646930385796-0">
# <script>googletag.cmd.push(function() {googletag.display('div-gpt-ad-1646930385796-0');});
#     </script>
# </div> </div>
# <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/stem-inc-continues-to-guide-for-ebitda-positive-2024-despite-q1-revenue-and-bookings-dip/">
# <img alt="A Stem Inc battery storage project. Image: Stem Inc." height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/CI_Photo_3_Stem_Inc-pb0zo5ss853t1m50a22puk5kna9yyljlptmw5iygg4.png" title="CI_Photo_3_Stem_Inc" width="400"/> </a>
# </div>
# <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/stem-inc-continues-to-guide-for-ebitda-positive-2024-despite-q1-revenue-and-bookings-dip/">Stem Inc continues to guide for EBITDA positive 2024 despite Q1 revenue and bookings dip</a></h2> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# Stem Inc has reaffirmed guidance of positive adjusted EBITDA for 2024, despite starting the year with a 62% year-on-year decrease in reported revenues and a fall in bookings. </div>
# <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/fluence-revenue-drop-new-5mwh-20-foot-product-and-us-made-modules-for-domestic-content-in-2024/">
# <img alt="Fluence" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/Fluence-Energy-Storage_3_web-q98zmumzvywsh0vkvqx189tjyzoef9i8vzyai7eqpw.jpg" title="Fluence-Energy-Storage_3_web" width="400"/> </a>
# </div>
# <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/fluence-revenue-drop-new-5mwh-20-foot-product-and-us-made-modules-for-domestic-content-in-2024/">Fluence revenue drop, new 5MWh 20-foot product and US-made modules for domestic content in 2024</a></h2> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# Global battery energy storage system (BESS) integrator Fluence saw an 11% revenue drop in revenues in the three months ending 31 March, 2024, while it is also launching a higher energy density product and US module production this year. </div>
# <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/queensland-to-build-1200mwh-publicly-owned-battery-storage-asset-at-stanwell-coal-power-station/">
# <img alt="A rendering of Stanwell Clean Energy Hub. Image: Queensland government." height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/Stanwell-Clean-Energy-Hub_LR-credit-queensland-government-1-qdfx0q2djv4n5e8rbqejatkn5uxy53dtndrheqk98k.jpg" title="Stanwell Clean Energy Hub_LR credit queensland government" width="400"/> </a>
# </div>
# <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/queensland-to-build-1200mwh-publicly-owned-battery-storage-asset-at-stanwell-coal-power-station/">Queensland to build 1,200MWh publicly-owned battery storage asset at Stanwell coal power station</a></h2> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# The state of Queensland, Australia, has committed to investing AU$448 million into battery storage technology at a coal power plant. </div>
# <div class="elementor-widget-container">
# <a href="https://www.energy-storage.news/regulator-approves-global-energy-alliance-for-people-and-planets-first-project-in-1gw-india-bess-pipeline/">
# <img alt="GEAPP's BESS Consortium launched at last year's COP28 talks. Image: UNclimatechange via Flickr" height="250" loading="lazy" src="https://www.energy-storage.news/wp-content/uploads/elementor/thumbs/COP28-credit-UNclimate-change-via-flickr-qnwdy4dsysu3vofihixjfldn0jc9exzqevxpkcd6f8.jpg" title="COP28 credit UNclimate change via flickr" width="400"/> </a>
# </div>
# <div class="elementor-widget-container">
# <h2 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/regulator-approves-global-energy-alliance-for-people-and-planets-first-project-in-1gw-india-bess-pipeline/">Regulator approves Global Energy Alliance for People and Planet’s first project in 1GW India BESS pipeline</a></h2> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 9, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# Regulatory approval has been granted for what is claimed to be India’s first commercial standalone battery storage project. </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/breaking-communication-barriers-between-asset-management-and-om-is-essential-for-ess-operations/">Breaking communication barriers between asset management and O&amp;M is essential for ESS operations</a></h3> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-terms"><span class="jet-listing-dynamic-terms__link">Premium</span></div> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/uk-residential-market-moving-from-solar-coupled-to-battery-first-says-givenergy/">UK residential market moving from solar-coupled to ‘battery first’, says GivEnergy</a></h3> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/india-tata-power-signs-ppa-for-firm-dispatchable-energy-from-wind-solar-and-storage/">India: Tata Power signs PPA for firm, dispatchable energy from wind, solar and storage</a></h3> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-terms"><span class="jet-listing-dynamic-terms__link">Premium</span></div> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/powin-says-diversity-of-bess-cell-supply-key-to-solving-post-pandemic-procurement-challenges/">Powin says diversity of BESS cell supply key to solving post-pandemic procurement challenges</a></h3> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-terms"><span class="jet-listing-dynamic-terms__link">Premium</span></div> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/netherlands-non-firm-grid-connections-and-lower-fees-could-double-bess-deployments/">Netherlands’ ‘non-firm’ grid connections and lower fees could double BESS deployments</a></h3> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.energy-storage.news/powin-joins-5mwh-bess-container-club-with-new-pod-unit/">Powin joins 5MWh BESS container club with new ‘Pod’ unit</a></h3> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://re-plus.events/texas/" target="_blank">RE+ Texas 2024</a></h3> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 14</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - May 15</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">Houston, Texas</div></div></div> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://app.livestorm.co/solar-media/learn-how-innovations-in-insurance-unlock-the-full-potential-of-battery-storage-systems?utm_source=ESN&amp;utm_medium=event-listings" target="_blank">Learn how innovations in insurance unlock the full potential of battery storage systems</a></h3> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 15</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - May 15</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">8am (EDT) / 2pm (CEST)</div></div></div> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://storageaustralia.solarenergyevents.com/" target="_blank">Energy Storage Summit Australia 2024</a></h3> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 21</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - May 22</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">Sydney, Australia</div></div></div> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://www.pvtechconferences.com/pv-moduletech-usa/?utm_source=calendar&amp;utm_medium=website&amp;utm_campaign=continual" target="_blank">PV ModuleTech USA 2024</a></h3> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 21</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - May 22</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">Napa, USA</div></div></div> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://renewablerevenue.co.uk/" target="_blank">Renewable Energy Revenues Summit 2024</a></h3> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">May 22</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - May 23</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">London, UK </div></div></div> </div>
# <div class="elementor-widget-container">
# <h3 class="elementor-heading-title elementor-size-default"><a href="https://acore.org/events/finance-forum/" target="_blank">ACORE Finance Forum 2024</a></h3> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">June 4</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content"> - June 5</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">, 2024</div></div></div> </div>
# <div class="elementor-widget-container">
# <div class="jet-listing jet-listing-dynamic-field display-inline"><div class="jet-listing-dynamic-field__inline-wrap"><div class="jet-listing-dynamic-field__content">New York, USA</div></div></div> </div>

# %%
html.mdl-js body.archive.tax-market-segments.term-grid-scale.term-9.wp-custom-logo.elementor-default.elementor-template-full-width.elementor-kit-6.elementor-page-510.e--ua-firefox.wkwp-action-active div.elementor.elementor-510.elementor-location-archive section.elementor-section.elementor-top-section.elementor-element.elementor-element-2886a85.elementor-section-boxed.elementor-section-height-default.jet-parallax-section div.elementor-container.elementor-column-gap-default div.elementor-column.elementor-col-66.elementor-top-column.elementor-element.elementor-element-ac4189d div.elementor-widget-wrap.elementor-element-populated div.elementor-element.elementor-element-4de41f9.elementor-widget.elementor-widget-jet-listing-grid div.elementor-widget-container div.jet-listing-grid.jet-listing div.jet-listing-grid__items.grid-col-desk-1.grid-col-tablet-1.grid-col-mobile-1.jet-listing-grid--513 div.jet-listing-grid__item.jet-listing-dynamic-post-53757 div.elementor.elementor-513 section.elementor-section.elementor-top-section.elementor-element.elementor-element-e6ad8cc.elementor-section-boxed.elementor-section-height-default.jet-parallax-section div.elementor-container.elementor-column-gap-default div.elementor-column.elementor-col-66.elementor-top-column.elementor-element.elementor-element-c8cccae div.elementor-widget-wrap.elementor-element-populated div.elementor-element.elementor-element-79cd234.elementor-widget.elementor-widget-text-editor div.elementor-widget-container

# %%
/html/body/div[2]/section/div[2]/div[1]/div/div[2]/div/div/div/div[1]/div/section/div[2]/div[2]/div/div[3]/div

# %%
all_results = soup.select('.jet-listing-dynamic-post-53757 > div:nth-child(1) > section:nth-child(1) > div:nth-child(2) > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div:nth-child(1)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4810/1377521722.py in <module>
# ----> 1 all_results = soup.select('.jet-listing-dynamic-post-53757 > div:nth-child(1) > section:nth-child(1) > div:nth-child(2) > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div:nth-child(1)')
#
# NameError: name 'soup' is not defined

# %%
.jet-listing-dynamic-post-53757 > div:nth-child(1) > section:nth-child(1) > div:nth-child(2) > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div:nth-child(1)

# %%
type(container_results)
# Out:
# bs4.element.ResultSet

# %%
import re
for item in container_results:
    s = item
    result = re.search('</div></div></div> </div>, <div class="elementor-widget-container">(.*)<a href', s)
    print(result.group(1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4810/3544120595.py in <module>
#       2 for item in container_results:
#       3     s = item
# ----> 4     result = re.search('</div></div></div> </div>, <div class="elementor-widget-container">(.*)<a href', s)
#       5     print(result.group(1))
#
# ~/anaconda3/lib/python3.9/re.py in search(pattern, string, flags)
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#     202
#     203 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object
